# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayancoding/First.cpp/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print("👋 Hi, I'm Md Ikramul Ansari")
# print("🎓 B.Tech CSE | B.P. Mandal College of Engineering, Madhepura")
# print("💡 Interested in AI, ML, and Data Analytics")
# print("🛠️ Projects using Python, ML, and JavaScript")
# print("🌐 Tech-Coordinator | Google Cloud Developer Member")

# %%
# %pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 77.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.9 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=ddf16ac55f122f19e8ab71c3d0f1a337b8587b42502cde8127ef2bcc4fcdc272
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
from deepface import DeepFace
from PIL import Image,ImageDraw
from IPython.display import display
# Out:
# 25-07-05 02:46:33 - Directory /root/.deepface has been created
# 25-07-05 02:46:33 - Directory /root/.deepface/weights has been created

# %%
image_path="/content/ead868abac1076a08b5b6295e581b3cb.jpg"
image=Image.open(image_path)
display(image)
DeepFace.analyze(img_path=image_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=518x612>
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 25-07-05 02:48:12 - facial_expression_model_weights.h5 will be downloaded...
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 239MB/s]
# Action: age:  25%|██▌       | 1/4 [00:00<00:01,  1.97it/s]    Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 25-07-05 02:48:14 - age_model_weights.h5 will be downloaded...
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   7%|▋         | 36.7M/539M [00:00<00:01, 364MB/s]
#  14%|█▍        | 77.6M/539M [00:00<00:01, 390MB/s]
#  22%|██▏       | 117M/539M [00:00<00:01, 372MB/s]
#  29%|██▊       | 155M/539M [00:00<00:01, 333MB/s]
# ...

# %%
DeepFace.analyze(img_path="/content/ead868abac1076a08b5b6295e581b3cb.jpg", detector_backend='retinaface')
# Out:
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# To: /root/.deepface/weights/retinaface.h5
# 25-07-05 02:48:35 - retinaface.h5 will be downloaded from the url https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# 100%|██████████| 119M/119M [00:00<00:00, 289MB/s]
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.10it/s]
# [{'emotion': {'angry': np.float32(0.045108136),
#    'disgust': np.float32(6.182935e-07),
#    'fear': np.float32(0.046245825),
#    'happy': np.float32(4.188608),
#    'sad': np.float32(1.2037714),
#    'surprise': np.float32(0.00079809915),
#    'neutral': np.float32(94.515465)},
#   'dominant_emotion': 'neutral',
#   'region': {'x': 143,
#    'y': 78,
#    'w': 213,
#    'h': 299,
#    'left_eye': (291, 208),
#    'right_eye': (190, 201)},
#   'face_confidence': np.float64(1.0),
#   'age': 29,
#   'gender': {'Woman': np.float32(99.9044), 'Man': np.float32(0.09560129)},
# ...

# %%
# Draw square around face

image_path="/content/ead868abac1076a08b5b6295e581b3cb.jpg"
image=Image.open(image_path)
analysis=DeepFace.analyze(image_path,detector_backend="retinaface")

region=analysis[0]['region']
draw=ImageDraw.Draw(image)
draw.rectangle((region['x'],region['y'],region['x']+region['w'],region['y']+region['h']),outline='green',width=3)

modified_image_path="/content/ead868abac1076a08b5b6295e581b3cb.jpg_modified.jpg"
image.save(modified_image_path)


image=Image.open(modified_image_path)
display(image)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.12it/s]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=518x612>

# %%
#verify the faces belong to the same person
display(Image.open("/content/ead868abac1076a08b5b6295e581b3cb.jpg"))
DeepFace.verify(img1_path="/content/ead868abac1076a08b5b6295e581b3cb.jpg",img2_path="/content/images.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=518x612>
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 25-07-05 02:48:58 - vgg_face_weights.h5 will be downloaded...
# 100%|██████████| 580M/580M [00:01<00:00, 336MB/s]
# {'verified': True,
#  'distance': 0.47516659072583534,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 103,
#    'y': 96,
#    'w': 280,
#    'h': 280,
#    'left_eye': (293, 209),
#    'right_eye': (186, 201)},
#   'img2': {'x': 45,
#    'y': 43,
#    'w': 93,
#    'h': 93,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 7.6}

# %%
#verify the faces don't belong to the same person
display(Image.open("/content/deepfake.jpeg"))
DeepFace.verify(img1_path="/content/donald drump.jpeg",img2_path="/content/deepfake.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>
# {'verified': True,
#  'distance': 0.6686164384560763,
#  'threshold': 0.68,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine',
#  'facial_areas': {'img1': {'x': 160,
#    'y': 71,
#    'w': 64,
#    'h': 78,
#    'left_eye': None,
#    'right_eye': None},
#   'img2': {'x': 101,
#    'y': 6,
#    'w': 26,
#    'h': 26,
#    'left_eye': None,
#    'right_eye': None}},
#  'time': 7.73}
